# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load 
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_rides_city = pyber_data_df.groupby(["type"]).count()["ride_id"]
total_rides_city = total_rides_city.rename("Total Rides")
total_rides_city.head()
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: Total Rides, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_drivers_city = city_data_df.groupby(["type"]).sum()["driver_count"]
total_drivers_city = total_drivers_city.rename ("Total Drivers")
total_drivers_city.head()
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: Total Drivers, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fares_city = pyber_data_df.groupby(["type"]).sum()["fare"]
total_fares_city = total_fares_city.rename ("Total Fares")
total_fares_city.head()
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: Total Fares, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
average_fares_ride = total_fares_city/total_rides_city
average_fares_ride = average_fares_ride.rename("Average Fare per Ride")
average_fares_ride.head()
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: Average Fare per Ride, dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
average_fares_perdriver_city = total_fares_city/total_drivers_city
average_fares_perdriver_city = average_fares_perdriver_city.rename("Average Fare per Driver")
average_fares_perdriver_city.head()
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# Name: Average Fare per Driver, dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.concat([total_rides_city, total_drivers_city,total_fares_city,average_fares_ride,
                                average_fares_perdriver_city], axis=1)
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df.dtypes
# Out:
# Total Rides                  int64
# Total Drivers                int64
# Total Fares                float64
# Average Fare per Ride      float64
# Average Fare per Driver    float64
# dtype: object

# %%
#  8. Format the columns.
pyber_summary_df.style.format({"Total Fares" : "${0:,.2f}","Average Fare per Ride" : "${0:,.2f}",
                               "Average Fare per Driver" : "${0:,.2f}" })
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c607_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Rides</th>
#       <th class="col_heading level0 col1" >Total Drivers</th>
#       <th class="col_heading level0 col2" >Total Fares</th>
#       <th class="col_heading level0 col3" >Average Fare per Ride</th>
#       <th class="col_heading level0 col4" >Average Fare per Driver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c607_level0_row0" class="row_heading level0 row0" >Rural</th>
#       <td id="T_6c607_row0_col0" class="data row0 col0" >125</td>
#       <td id="T_6c607_row0_col1" class="data row0 col1" >78</td>
#       <td id="T_6c607_row0_col2" class="data row0 col2" >$4,327.93</td>
#       <td id="T_6c607_row0_col3" class="data row0 col3" >$34.62</td>
#       <td id="T_6c607_row0_col4" class="data row0 col4" >$55.49</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
pyber_group_df = pyber_data_df.groupby(["type", "date"]).sum()[["fare"]]
pyber_group_df
# Out:
#                             fare
# type  date
# Rural 2019-01-01 09:45:36  43.69
#       2019-01-02 11:18:32  52.12
#       2019-01-03 19:51:01  19.90
#       2019-01-04 03:31:26  24.88
#       2019-01-06 07:38:40  47.33
# ...                          ...
# Urban 2019-05-08 04:20:00  21.99
#       2019-05-08 04:39:49  18.45
#       2019-05-08 07:29:01  18.55
#       2019-05-08 11:38:35  19.77
#       2019-05-08 13:10:18  18.04
#
# [2375 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
pyber_group_df_reset = pyber_group_df.reset_index()
pyber_group_df_reset
# Out:
#        type                 date   fare
# 0     Rural  2019-01-01 09:45:36  43.69
# 1     Rural  2019-01-02 11:18:32  52.12
# 2     Rural  2019-01-03 19:51:01  19.90
# 3     Rural  2019-01-04 03:31:26  24.88
# 4     Rural  2019-01-06 07:38:40  47.33
# ...     ...                  ...    ...
# 2370  Urban  2019-05-08 04:20:00  21.99
# 2371  Urban  2019-05-08 04:39:49  18.45
# 2372  Urban  2019-05-08 07:29:01  18.55
# 2373  Urban  2019-05-08 11:38:35  19.77
# 2374  Urban  2019-05-08 13:10:18  18.04
#
# [2375 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
pyber_group_pivot = pyber_group_df_reset.pivot (index = "date", columns="type", values= "fare")
pyber_group_pivot.head(10)
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# 2019-01-01 09:45:36  43.69       NaN    NaN
# 2019-01-01 12:32:48    NaN     25.56    NaN
# 2019-01-01 14:40:14    NaN       NaN   5.42
# 2019-01-01 14:42:25    NaN       NaN  12.31
# 2019-01-01 14:52:06    NaN     31.15    NaN

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
pyber_date_df = pyber_group_pivot.loc["2019-01-01": "2019-04-28"]
pyber_date_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-27 17:58:27  14.01       NaN    NaN
# 2019-04-27 19:45:48    NaN     28.84    NaN
# 2019-04-27 20:41:36    NaN       NaN   8.28
# 2019-04-27 23:26:03    NaN       NaN  19.06
# 2019-04-27 23:52:44    NaN     45.98    NaN
#
# [2177 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
pyber_date_df.index = pd.to_datetime(pyber_date_df.index)
pyber_date_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-27 17:58:27  14.01       NaN    NaN
# 2019-04-27 19:45:48    NaN     28.84    NaN
# 2019-04-27 20:41:36    NaN       NaN   8.28
# 2019-04-27 23:26:03    NaN       NaN  19.06
# 2019-04-27 23:52:44    NaN     45.98    NaN
#
# [2177 rows x 3 columns]

# %%
# 7. Check that the datatype for the index is datetime using df.info()
pyber_date_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2177 entries, 2019-01-01 00:08:16 to 2019-04-27 23:52:44
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  567 non-null    float64
#  2   Urban     1496 non-null   float64
# dtypes: float64(3)
# memory usage: 68.0 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
pyber_date_df_week =pyber_date_df.resample("W").sum()
pyber_date_df_week.head(10)
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
weekly_fare = pyber_date_df_week.plot(figsize = (20,6), color= ["blue","red","orange"])
# Add a title 
weekly_fare.set_title("Total Fare By City Type",{"fontsize":20})
#  Add a x- and y-axis label.
weekly_fare.set_xlabel("Months",{"fontsize":16})
weekly_fare.set_ylabel("Fare($USD)", {"fontsize":16})
# Save Figure
plt.savefig("analysis/PyBer_fare_summary.png")

plt.show()
plt.tight_layout()
